# %%
import pandas as pd

# %%
sells_INN = pd.read_csv(r"D:\Analysys Burn\Википедия\БЁРН исходники\Оптовые и розничные продажи по ИНН\Оптовые и розничные продажи ИНН.csv", 
                        dtype={'ИНН продавца':str, 'ИНН покупателя' : str})

# %%
sells_INN.head()
# Out:
#   Дата операции  ИНН производителя Наименование производителя  ИНН продавца  \
# 0    2023-03-30         5047205725                 ООО "БЁРН"  7743931676.0
# 1    2023-03-30         5047205725                 ООО "БЁРН"  7743931676.0
# 2    2023-03-27         5047205725                 ООО "БЁРН"  5047205725.0
# 3    2023-03-27         5047205725                 ООО "БЁРН"  5047205725.0
# 4    2023-03-30         5047205725                 ООО "БЁРН"  7743931676.0
#
#                                Наименование продавца  ИНН покупателя  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЛЬФ...             NaN
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЛЬФ...             NaN
# 2                                         ООО "БЁРН"  500725710690.0
# 3                                         ООО "БЁРН"  500725710690.0
# 4  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЛЬФ...             NaN
#
#        Наименование покупателя           GTIN      ТН ВЭД  \
# ...

# %%
burn = sells_INN.loc[sells_INN['ИНН продавца'] =='5047205725.0']

# %%
burn.head(2)
# Out:
#   Дата операции  ИНН производителя Наименование производителя  ИНН продавца  \
# 2    2023-03-27         5047205725                 ООО "БЁРН"  5047205725.0
# 3    2023-03-27         5047205725                 ООО "БЁРН"  5047205725.0
#
#   Наименование продавца  ИНН покупателя      Наименование покупателя  \
# 2            ООО "БЁРН"  500725710690.0  ИП Межевич Мария Дмитриевна
# 3            ООО "БЁРН"  500725710690.0  ИП Межевич Мария Дмитриевна
#
#             GTIN      ТН ВЭД  \
# 2  4650190059249  2403110000
# 3  4650259252062  2403110000
#
#                                  Наименование товара        Тип операции  \
# 2  Табак для кальяна Overdose Kashmir Citrus (Каш...  Передача между УОТ
# 3  Табак для кальяна Overdose Sweet Rose (Ягоды с...  Передача между УОТ
#
#    Объем товара (пачек)  МРЦ
# 2                  1660    0
# 3                  1660    0

# %%
burnTH = burn['ИНН покупателя'].unique()

# %%
burnTH = pd.DataFrame(pd.Series(burnTH))

# %%
burnTH
# Out:
#                  0
# 0   500725710690.0
# 1     7715441408.0
# 2   910410435493.0
# 3   771977475703.0
# 4   772585029805.0
# 5   481106564441.0
# 6   503901106403.0
# 7    54604646501.0
# 8   500724650920.0
# 9   165128176030.0
# 10  504904832684.0
# 11  502986284305.0
# 12  781427975280.0
# 13    5406809232.0
# 14  237304896570.0
# 15  263606528239.0
# 16  151301044939.0
# 17  615490981930.0
# 18  101601626870.0
# 19  614306474880.0
# 20  470313789220.0
# 21    7810751939.0
# 22  101602387208.0
# 23  780251976084.0
# 24  220809176398.0
# 25  381608573800.0
