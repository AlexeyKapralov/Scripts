# %%
import pandas as pd

# %%
distributors = [
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Астрахань Рзаев\Sell_out_Астрахань_Рзаев.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Барнаул Hookah People\Sell_out_Барнаул_Hookah_People.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Брянск ЦЕНТРТАБАККО\Sell_out_брянск_центртабакко.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Волгоград Погосян\Sell_Out_Волгоград_Погосян.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Вологда Порохин\Sell_out_Вологда_Порохин.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Екатеринбург Урал табак\Sell_Out_Екатеринбург_Уралтабак.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Иваново Ориджиналс\Sell_Out_Иваново_Ориджиналс.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Казань Best Shop\Sell_Out_Казань_Best_Shop.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Калининград Прокопкин\Sell_Out_Калининград_Прокопкин.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Киров МакоффМаркет\Sell_Out_Киров_МакоффМаркет.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Кострома Зайцева\Sell_Out_Кострома_Зайцева.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Краснодар Склад\Sell_Out_Краснодар_Склад.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Красноярск НУА\Sell_Out_Красноярск_НУА.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Москва OSHISHA\Sell_out_Москва_OSHISHA.csv",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Нижний Новгород Пармаркет\Sell_Out_Нижний_Новгород_Пар_Маркет.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Новороссийск Клец\Sell_Out_Новороссийск_Клец.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Новосибирск Поставь Угли\Sell_Out_Новосибирск_Поставь_угли.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Новосибирск БС-Трейд\Sell_Out_Новосибирск_БС_Трейд.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Пермь Файзуллин\Sell_Out_Пермь_Файзуллин.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Санкт-Петербург СмокЛаб\Sell_Out_Санкт_Петербург_СмокЛаб.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Санкт Петербург S2B ИП Дрига\Sell_Out_Санкт_Петербург_S2B.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Саранск Соломатин\Sell_Out_Саранск_Соломатин.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Саратов Череваткин\Sell_Out_Саратов_Череваткин.xlsx", 
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Севастополь Белоглазов\Sell_Out_Севастополь_Белоглазов.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Сочи, Адлер Непомнящие\Sell_Out_Сочи_Непомнящие.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Тверь Друг дыма\Sell_Out_Тверь_Друг_Дыма.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Томск СВ Трейд\Sell_Out_Томск_СВ_Трейд.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Тюмень Алатырь\Sell_Out_Тюмень_Алатырь.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Хабаровск Дока\Sell_Out_Хабаровск_Дока.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Хабаровск Хука Стор ИП Халтурин\Sell_Out_Хабаровск_Халтурин.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Челябинск Мыкалов\Sell_Out_Челябинск_Мыкалов.xlsx",
    "D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Череповец Полежаев\Sell_Out_Череповец_Полежаев.xlsx", 
]

# %%
df = pd.read_excel(r"D:\Analysis Burn\Дистрибьютеры отчетность\Source\Отчеты\Череповец Полежаев\Sell_Out_Череповец_Полежаев.xlsx")

# %%
a = df.columns.values

# %%
a = pd.Series(['Торговый представитель', 'Код клиента', 'Сегмент', 'Клиент',
       'Адрес доставки', 'Дата отгрузки', 'Бренд', 'Группа', 'Вкус',
       'Граммовка', 'Количество шт', 'ВЕС', 'Цена', 'стоимость',
       'Дистрибьютор'])

# %%
### чтение общего файла продаж в зависимости от типа
# чтение если csv
if sell_out_path_for_good_file.endswith(".csv"):
    is_csv = True
    if sell_out_path_for_good_file != '':
        good_sell_out = pd.read_csv(sell_out_path_for_good_file)
# чтение если excel
if sell_out_path_for_good_file.endswith(".xlsx"):
    is_csv = False
    if sell_out_path_for_good_file != '':
        good_sell_out = pd.read_excel(sell_out_path_for_good_file)

# %%
li = []
for i in distributors:

    if i.endswith(".csv"):
        is_csv = True
        if i != '':
            df = pd.read_csv(i)
    # чтение если excel
    if i.endswith(".xlsx"):
        is_csv = False
        if i != '':
            df = pd.read_excel(i)


    if pd.Series(df.columns.values).equals(a) == False:
        print("Ошибка в колонках " + i)
        exit()
     

    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
dist = pd.read_excel(r"D:\Analysis Burn\Дистрибьюторы Burn.xlsx")

# %%
dist
# Out:
#       Регион            Город                                Партнер   \
# 0        ЮФО          Армавир                                Петренко
# 1       СЗФО      Архангельск                Дзюба Дмитрий Викторович
# 2        ЮФО        Астрахань                               ИП Рзаев
# 3        ЮФО        Волгоград  Двойное яблоко ИП Ханами Айсар/Евгения
# 4    Экспорт  Беларусь, Минск                              ИП Яковлев
# ..       ...              ...                                     ...
# 109      УФО           Тюмень                       Алатырь Смоук Лаб
# 110     ДВФО        Хабаровск                             ИП Халтурин
# 111      УФО        Челябинск                        Мыкалов Владимир
# 112     СЗФО        Череповец                          Полежаев Антон
# 113     ДВФО           Якутск                                ИП Зонов
#
#              Менеджер   Уникальный идентификатор  \
# 0           Губин Юрий                        44
# ...

# %%
dist[['Уникальный идентификатор', 'Город', 'Партнер ', 'Менеджер ']]
# Out:
#      Уникальный идентификатор            Город  \
# 0                          44          Армавир
# 1                          48      Архангельск
# 2                          35        Астрахань
# 3                         103        Волгоград
# 4                          50  Беларусь, Минск
# ..                        ...              ...
# 109                        31           Тюмень
# 110                       101        Хабаровск
# 111                       106        Челябинск
# 112                        82        Череповец
# 113                       117           Якутск
#
#                                    Партнер           Менеджер
# 0                                  Петренко         Губин Юрий
# 1                  Дзюба Дмитрий Викторович    Кузнецов Андрей
# 2                                 ИП Рзаев          Губин Юрий
# 3    Двойное яблоко ИП Ханами Айсар/Евгения         Губин Юрий
# 4                                ИП Яковлев    Кузнецов Андрей
# ...

# %%
frame2 = frame.merge(
    dist[['Уникальный идентификатор', 'Город', 'Партнер ', 'Менеджер ']], 
    how="left",
    left_on='Дистрибьютор',
    right_on='Уникальный идентификатор'
)

# %%
frame2.columns
# Out:
# Index(['Торговый представитель', 'Код клиента', 'Сегмент', 'Клиент',
#        'Адрес доставки', 'Дата отгрузки', 'Бренд', 'Группа', 'Вкус',
#        'Граммовка', 'Количество шт', 'ВЕС', 'Цена', 'стоимость',
#        'Дистрибьютор', 'Уникальный идентификатор', 'Город', 'Партнер ',
#        'Менеджер '],
#       dtype='object')

# %%
frame2['Клиент'] = frame2['Клиент'].str.lower()

# %%
frame2['Адрес доставки'] = frame2['Адрес доставки'].str.lower()

# %%
frame2
# Out:
#                Торговый представитель Код клиента                Сегмент  \
# 0              Рзаев Азер Физули Оглы  не указано              кальянная
# 1              Рзаев Азер Физули Оглы  не указано              кальянная
# 2              Рзаев Азер Физули Оглы  не указано              кальянная
# 3              Рзаев Азер Физули Оглы  не указано              кальянная
# 4              Рзаев Азер Физули Оглы  не указано              кальянная
# ...                               ...         ...                    ...
# 1302176  ип полежаев антон валерьевич         556                     []
# 1302177  ип полежаев антон валерьевич          64  [покупатели, розница]
# 1302178  ип полежаев антон валерьевич          64  [покупатели, розница]
# 1302179  ип полежаев антон валерьевич          64  [покупатели, розница]
# 1302180  ип полежаев антон валерьевич          64  [покупатели, розница]
#
#                                Клиент Адрес доставки        Дата отгрузки  \
# ...

# %%
frame2.groupby(
    by=['Город', 'Менеджер ', 'Клиент', 'Адрес доставки']
)['Торговый представитель'].count().reset_index().to_excel(r"C:\Users\User\Desktop\Клиентская база.xlsx")
