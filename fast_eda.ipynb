# %%
import pandas as pd
from fasteda import fast_eda

# %%
df = pd.read_excel(r"D:\Analysis Burn\Аналитика телеграм бота\Исходные\её_менять_для_dashboard.xlsx")

# %%
fast_eda(df)
# Out:
# DataFrame Head:
#    ID в телеграм  Кол-во баллов                            ФИО  \
# 0      406905174          103.0     Ефименко Андрей Алексеевич
# 1     1725851255          100.0  Неберт Алексей Константинович
# 2      868876570            2.0  Иванова Александра Валерьевна
#
#                         e-mail    Номер телефона      Город  \
# 0        gniloyworld@gmail.com       79535663186     Казань
# 1          leshanebert@mail.ru  +7(908)027-94-02  Ярославль
# 2  alexsandra09sudak@yandex.ru  +7(978)832-50-48       Ялта
#
#                 Регион Почтовый индекс Дата регистрации  \
# 0            Татарстан          420097       14.04.2023
# 1  Ярославская область          150000       04.05.2023
# 2      Республика Крым          298000       24.04.2023
#
#    Кол-во посещенных мероприятий  Кол-во попыток активации  \
# 0                              0                         0
# 1                              0                         0
# 2                              0                         8
#
#   Значение при присоединении Категория  Кол-во заказов  Кол-во выигрышей  \
# 0               BB025LKFLVSK  Любитель               0               NaN
# 1                        NaN  Любитель               0               NaN
# 2               OD10046VDLNZ       NaN               0               NaN
#
#    Кол-во отсканированных кодов QR-код при присоединении  \
# 0                             0                      NaN
# 1                             0                      NaN
# 2                             8                      NaN
#
#   Статическая ссылка при присоединении  Мероприятие при присоединении  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
#
#   Кем был приглашен  Кол-во приглашенных пользователей
# 0               NaN                                  0
# 1               NaN                                  0
# 2               NaN                                  0
# DataFrame Tail:
#        ID в телеграм  Кол-во баллов                            ФИО  \
# 14929      343150009            0.0        Струнин Аким Максимович
# 14930         197281            1.0  Ахвердиев Элдар Таджаддинович
# 14931     5976026352            1.0   Полянская Варвара Дмитриевна
#
#                           e-mail    Номер телефона                 Город  \
# 14929  ack.strunin2014@yandex.ru  +7(980)751-69-70  поселение Московский
# 14930              el-ne@mail.ru  +7(953)347-25-87       Санкт-Петербург
# 14931   polanskaavara5@gmail.com      +79613805372                Самара
#
#                   Регион Почтовый индекс Дата регистрации  \
# 14929             Москва          108802       14.04.2023
# 14930    Санкт-Петербург          198335       14.04.2023
# 14931  Самарская область          443028       22.07.2023
#
#        Кол-во посещенных мероприятий  Кол-во попыток активации  \
# 14929                              0                       121
# 14930                              0                        33
# 14931                              0                         0
#
#       Значение при присоединении         Категория  Кол-во заказов  \
# 14929                        NaN  Кальянный мастер               1
# 14930               BB100XCFRWA6          Любитель               0
# 14931                        NaN  Кальянный мастер               1
#
#        Кол-во выигрышей  Кол-во отсканированных кодов  \
# 14929               1.0                           101
# 14930               NaN                            35
# 14931               1.0                             0
#
#       QR-код при присоединении Статическая ссылка при присоединении  \
# 14929                      NaN                                  NaN
# 14930             BB100XCFRWA6                                  NaN
# 14931                      NaN                                  NaN
#
#        Мероприятие при присоединении Кем был приглашен  \
# 14929                            NaN               NaN
# 14930                            NaN               NaN
# 14931                            NaN               NaN
#
#        Кол-во приглашенных пользователей
# 14929                                  0
# 14930                                  0
# 14931                                  0
# ----------------------------------------------------------------------------------------------------
# Missing values:
# <style type="text/css">
# #T_78713_row0_col0, #T_78713_row1_col0, #T_78713_row2_col0, #T_78713_row3_col0, #T_78713_row4_col0, #T_78713_row5_col0, #T_78713_row6_col0, #T_78713_row7_col0, #T_78713_row8_col0, #T_78713_row9_col0 {
#   background-color: #000000;
#   color: #ff0000;
#   font-weight: bold;
# }
# </style>
# <table id="T_78713">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78713_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78713_level0_row0" class="row_heading level0 row0" >Город</th>
#       <td id="T_78713_row0_col0" class="data row0 col0" >306</td>
#     </tr>
#     <tr>
#       <th id="T_78713_level0_row1" class="row_heading level0 row1" >Регион</th>
#       <td id="T_78713_row1_col0" class="data row1 col0" >113</td>
#     </tr>
#     <tr>
#       <th id="T_78713_level0_row2" class="row_heading level0 row2" >Почтовый индекс</th>
#       <td id="T_78713_row2_col0" class="data row2 col0" >263</td>
#     </tr>
#     <tr>
#       <th id="T_78713_level0_row3" class="row_heading level0 row3" >Значение при присоединении</th>
#       <td id="T_78713_row3_col0" class="data row3 col0" >5060</td>
#     </tr>
#     <tr>
#       <th id="T_78713_level0_row4" class="row_heading level0 row4" >Категория</th>
#       <td id="T_78713_row4_col0" class="data row4 col0" >1684</td>
#     </tr>
#     <tr>
#       <th id="T_78713_level0_row5" class="row_heading level0 row5" >Кол-во выигрышей</th>
#       <td id="T_78713_row5_col0" class="data row5 col0" >14392</td>
#     </tr>
#     <tr>
#       <th id="T_78713_level0_row6" class="row_heading level0 row6" >QR-код при присоединении</th>
#       <td id="T_78713_row6_col0" class="data row6 col0" >12132</td>
#     </tr>
#     <tr>
#       <th id="T_78713_level0_row7" class="row_heading level0 row7" >Статическая ссылка при присоединении</th>
#       <td id="T_78713_row7_col0" class="data row7 col0" >12136</td>
#     </tr>
#     <tr>
#       <th id="T_78713_level0_row8" class="row_heading level0 row8" >Мероприятие при присоединении</th>
#       <td id="T_78713_row8_col0" class="data row8 col0" >14932</td>
#     </tr>
#     <tr>
#       <th id="T_78713_level0_row9" class="row_heading level0 row9" >Кем был приглашен</th>
#       <td id="T_78713_row9_col0" class="data row9 col0" >14930</td>
#     </tr>
#   </tbody>
# </table>
# ----------------------------------------------------------------------------------------------------
# MSNO Matrix:
# ----------------------------------------------------------------------------------------------------
# Shape of DataFrame:
#
# (14932, 21)
#
# ----------------------------------------------------------------------------------------------------
# DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14932 entries, 0 to 14931
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID в телеграм                         14932 non-null  int64
#  1   Кол-во баллов                         14932 non-null  float64
#  2   ФИО                                   14932 non-null  object
#  3   e-mail                                14932 non-null  object
#  4   Номер телефона                        14932 non-null  object
#  5   Город                                 14626 non-null  object
#  6   Регион                                14819 non-null  object
#  7   Почтовый индекс                       14669 non-null  object
#  8   Дата регистрации                      14932 non-null  object
#  9   Кол-во посещенных мероприятий         14932 non-null  int64
#  10  Кол-во попыток активации              14932 non-null  int64
#  11  Значение при присоединении            9872 non-null   object
#  12  Категория                             13248 non-null  object
#  13  Кол-во заказов                        14932 non-null  int64
#  14  Кол-во выигрышей                      540 non-null    float64
#  15  Кол-во отсканированных кодов          14932 non-null  int64
#  16  QR-код при присоединении              2800 non-null   object
#  17  Статическая ссылка при присоединении  2796 non-null   object
#  18  Мероприятие при присоединении         0 non-null      float64
#  19  Кем был приглашен                     2 non-null      object
#  20  Кол-во приглашенных пользователей     14932 non-null  int64
# dtypes: float64(3), int64(6), object(12)
# memory usage: 2.4+ MB
# ----------------------------------------------------------------------------------------------------
# Describe DataFrame:
# c:\ProgramData\anaconda3\envs\analytics\lib\site-packages\scipy\stats\_stats_py.py:1193: RuntimeWarning: Mean of empty slice.
#   mean = a.mean(axis, keepdims=True)
# c:\ProgramData\anaconda3\envs\analytics\lib\site-packages\numpy\core\_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# c:\ProgramData\anaconda3\envs\analytics\lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\ProgramData\anaconda3\envs\analytics\lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\ProgramData\anaconda3\envs\analytics\lib\site-packages\scipy\stats\_stats_py.py:1303: RuntimeWarning: Mean of empty slice.
#   mean = a.mean(axis, keepdims=True)
# c:\ProgramData\anaconda3\envs\analytics\lib\site-packages\numpy\core\_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# c:\ProgramData\anaconda3\envs\analytics\lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\ProgramData\anaconda3\envs\analytics\lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# <style type="text/css">
# #T_d83af_row0_col0, #T_d83af_row0_col1, #T_d83af_row0_col2, #T_d83af_row0_col3, #T_d83af_row0_col4, #T_d83af_row0_col5, #T_d83af_row0_col6, #T_d83af_row0_col7, #T_d83af_row0_col8, #T_d83af_row1_col0, #T_d83af_row2_col0, #T_d83af_row3_col0, #T_d83af_row4_col0, #T_d83af_row6_col0, #T_d83af_row8_col0 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d83af_row0_col9, #T_d83af_row0_col10, #T_d83af_row1_col9, #T_d83af_row1_col10, #T_d83af_row2_col9, #T_d83af_row2_col10, #T_d83af_row3_col9, #T_d83af_row3_col10, #T_d83af_row4_col9, #T_d83af_row4_col10, #T_d83af_row5_col9, #T_d83af_row5_col10, #T_d83af_row6_col9, #T_d83af_row6_col10, #T_d83af_row7_col9, #T_d83af_row7_col10, #T_d83af_row8_col9, #T_d83af_row8_col10 {
#   color: #FFFFFF;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_d83af_row1_col1, #T_d83af_row1_col2, #T_d83af_row1_col3, #T_d83af_row1_col4, #T_d83af_row1_col5, #T_d83af_row1_col6, #T_d83af_row1_col7, #T_d83af_row1_col8, #T_d83af_row2_col1, #T_d83af_row2_col2, #T_d83af_row2_col3, #T_d83af_row2_col4, #T_d83af_row2_col5, #T_d83af_row2_col6, #T_d83af_row2_col7, #T_d83af_row2_col8, #T_d83af_row3_col1, #T_d83af_row3_col2, #T_d83af_row3_col3, #T_d83af_row3_col4, #T_d83af_row3_col5, #T_d83af_row3_col6, #T_d83af_row3_col7, #T_d83af_row3_col8, #T_d83af_row4_col1, #T_d83af_row4_col2, #T_d83af_row4_col3, #T_d83af_row4_col4, #T_d83af_row4_col5, #T_d83af_row4_col6, #T_d83af_row4_col7, #T_d83af_row4_col8, #T_d83af_row5_col1, #T_d83af_row5_col2, #T_d83af_row5_col3, #T_d83af_row5_col4, #T_d83af_row5_col5, #T_d83af_row5_col6, #T_d83af_row5_col7, #T_d83af_row5_col8, #T_d83af_row6_col1, #T_d83af_row6_col2, #T_d83af_row6_col3, #T_d83af_row6_col4, #T_d83af_row6_col5, #T_d83af_row6_col6, #T_d83af_row6_col7, #T_d83af_row6_col8, #T_d83af_row7_col0, #T_d83af_row8_col1, #T_d83af_row8_col2, #T_d83af_row8_col3, #T_d83af_row8_col4, #T_d83af_row8_col5, #T_d83af_row8_col6, #T_d83af_row8_col7, #T_d83af_row8_col8 {
#   background-color: #9e0142;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d83af_row5_col0 {
#   background-color: #b11747;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d83af_row7_col1, #T_d83af_row7_col2, #T_d83af_row7_col3, #T_d83af_row7_col4, #T_d83af_row7_col5, #T_d83af_row7_col6, #T_d83af_row7_col7, #T_d83af_row7_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_d83af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d83af_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_d83af_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_d83af_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_d83af_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_d83af_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_d83af_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_d83af_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_d83af_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_d83af_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_d83af_level0_col9" class="col_heading level0 col9" >skewness</th>
#       <th id="T_d83af_level0_col10" class="col_heading level0 col10" >kurtosis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d83af_level0_row0" class="row_heading level0 row0" >ID в телеграм</th>
#       <td id="T_d83af_row0_col0" class="data row0 col0" >14932</td>
#       <td id="T_d83af_row0_col1" class="data row0 col1" >1254870299.502</td>
#       <td id="T_d83af_row0_col2" class="data row0 col2" >775818333</td>
#       <td id="T_d83af_row0_col3" class="data row0 col3" >1489749739.029</td>
#       <td id="T_d83af_row0_col4" class="data row0 col4" >43628</td>
#       <td id="T_d83af_row0_col5" class="data row0 col5" >450464436.75</td>
#       <td id="T_d83af_row0_col6" class="data row0 col6" >775818333</td>
#       <td id="T_d83af_row0_col7" class="data row0 col7" >1222815590.5</td>
#       <td id="T_d83af_row0_col8" class="data row0 col8" >6691529985</td>
#       <td id="T_d83af_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_d83af_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d83af_level0_row1" class="row_heading level0 row1" >Кол-во баллов</th>
#       <td id="T_d83af_row1_col0" class="data row1 col0" >14932</td>
#       <td id="T_d83af_row1_col1" class="data row1 col1" >49.43</td>
#       <td id="T_d83af_row1_col2" class="data row1 col2" >6.5</td>
#       <td id="T_d83af_row1_col3" class="data row1 col3" >64.42</td>
#       <td id="T_d83af_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_d83af_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_d83af_row1_col6" class="data row1 col6" >6.5</td>
#       <td id="T_d83af_row1_col7" class="data row1 col7" >100</td>
#       <td id="T_d83af_row1_col8" class="data row1 col8" >937</td>
#       <td id="T_d83af_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_d83af_row1_col10" class="data row1 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d83af_level0_row2" class="row_heading level0 row2" >Кол-во посещенных мероприятий</th>
#       <td id="T_d83af_row2_col0" class="data row2 col0" >14932</td>
#       <td id="T_d83af_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_d83af_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_d83af_row2_col3" class="data row2 col3" >0.018</td>
#       <td id="T_d83af_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_d83af_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_d83af_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_d83af_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_d83af_row2_col8" class="data row2 col8" >2</td>
#       <td id="T_d83af_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_d83af_row2_col10" class="data row2 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d83af_level0_row3" class="row_heading level0 row3" >Кол-во попыток активации</th>
#       <td id="T_d83af_row3_col0" class="data row3 col0" >14932</td>
#       <td id="T_d83af_row3_col1" class="data row3 col1" >4.044</td>
#       <td id="T_d83af_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_d83af_row3_col3" class="data row3 col3" >13.736</td>
#       <td id="T_d83af_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_d83af_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_d83af_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_d83af_row3_col7" class="data row3 col7" >3</td>
#       <td id="T_d83af_row3_col8" class="data row3 col8" >756</td>
#       <td id="T_d83af_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_d83af_row3_col10" class="data row3 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d83af_level0_row4" class="row_heading level0 row4" >Кол-во заказов</th>
#       <td id="T_d83af_row4_col0" class="data row4 col0" >14932</td>
#       <td id="T_d83af_row4_col1" class="data row4 col1" >0.036</td>
#       <td id="T_d83af_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_d83af_row4_col3" class="data row4 col3" >0.197</td>
#       <td id="T_d83af_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_d83af_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_d83af_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_d83af_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_d83af_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_d83af_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_d83af_row4_col10" class="data row4 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d83af_level0_row5" class="row_heading level0 row5" >Кол-во выигрышей</th>
#       <td id="T_d83af_row5_col0" class="data row5 col0" >540</td>
#       <td id="T_d83af_row5_col1" class="data row5 col1" >1.183</td>
#       <td id="T_d83af_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_d83af_row5_col3" class="data row5 col3" >0.892</td>
#       <td id="T_d83af_row5_col4" c
# ----------------------------------------------------------------------------------------------------
# DataFrame Correlation:
# c:\ProgramData\anaconda3\envs\analytics\lib\site-packages\fasteda\__init__.py:130: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, cmap = "Spectral", linewidths = 2, linecolor = "#000000", fmt='.1f')
# ----------------------------------------------------------------------------------------------------
# Histogram(s) & Boxplot(s):
# ----------------------------------------------------------------------------------------------------
# Countplot(s):
